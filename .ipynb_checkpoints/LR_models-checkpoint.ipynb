# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier
import matplotlib.pyplot as plt
# SK-learn libraries for evaluation.
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import classification_report
from scipy.sparse import hstack

pd.options.display.max_rows = 99999
plt.style.use('dark_background')

# %%
X_test = pd.read_pickle('./data/test_dat.pkl')
n=len(X_test)
X_test = X_test.sample(n, replace=False).reset_index(drop=True)
X_train=X_test.iloc[:round(n*.5)]
X_test=X_test.iloc[round(n*.5):round(n*.8)]
print("Train shape ",X_train.shape)
print("Test shape ",X_test.shape)
# Out:
# Train shape  (60090, 5)
# Test shape  (36054, 5)

# %%
# Load data
X_train = pd.read_pickle('./data/training_dat_eng.pkl')
X_test = pd.read_pickle('./data/test_dat_eng.pkl')
print("Train shape ",X_train.shape)
print("Test shape ",X_test.shape)
# Out:
# Train shape  (480718, 5)
# Test shape  (120180, 5)

# %%
X_train.head()
# Out:
#    useful       date  stars  \
# 0       5 2015-10-13      5
# 1       5 2015-09-21      4
# 2      11 2013-04-07      5
# 3       8 2015-02-16      5
# 4       5 2015-10-22      4
#
#                                                 text  isuseful
# 0  Great office and really modern, staff is super...         1
# 1  Restaurant review\nIn my quest to eat at every...         1
# 2  'Twas a bleak Friday evening for pizza options...         1
# 3  These guys are good!  I called in Wednesday af...         1
# 4  I'm tellin you...this place used to be a strip...         1

# %%
X_train.isuseful.mean()
# Out:
# 0.5

# %%
X_test.head()
# Out:
#         useful       date  stars  \
# 240359      18 2013-07-29      5
# 240360      10 2016-04-18      5
# 240361      13 2014-06-11      5
# 240362       8 2017-02-08      3
# 240363       6 2015-02-20      4
#
#                                                      text  isuseful
# 240359  The Stand is simply delicious!!!!\nThey will h...         1
# 240360  Hobak in chinese letters means to get together...         1
# 240361  I hate doing laundry. ABSOLUTELY HATE it and I...         1
# 240362  Kung Fu Noodle at First Markham Place is a dec...         1
# 240363  Very authentic food and fantastic atmosphere. ...         1

# %%
X_test.isuseful.mean()
# Out:
# 0.5

# %% [markdown]
# # Simple BOW without any cleaning

# %%
tf_vectorizer = CountVectorizer()
tf_train = tf_vectorizer.fit_transform(X_train['text'])
tf_test = tf_vectorizer.transform(X_test['text'])
print("size of vocabulary")
print(len(tf_vectorizer.vocabulary_))
print("")

# add star features
tf_train = hstack((tf_train,np.array(X_train['stars'])[:,None]))
tf_test = hstack((tf_test,np.array(X_test['stars'])[:,None]))
print("train shape",tf_train.shape)
print("test shape",tf_test.shape)
# Out:
# size of vocabulary
# 99311

# %%
np.random.seed(42)

[tf_vectorizer.get_feature_names()[i] for i in np.random.choice(range(238963),
                                                               size=20,
                                                               replace=False)]
# Out:
# ['cuon',
#  'ekko',
#  'foils',
#  'liytle',
#  'ándres',
#  'tomatigem',
#  'with4',
#  '120out',
#  '0cphorlomtosqw1erxb6ta',
#  'senioritàs',
#  'anglaise',
#  'hammerheads',
#  'genki',
#  'boar',
#  'mintues',
#  'cupcakes',
#  'reparatur',
#  'stlawrencemarket',
#  'profitably',
#  'hoover']

# %%
LR = SGDClassifier(random_state=42,
                   loss='log', #logistic regression,
                   max_iter=100,
                   tol=1e-4,
                   n_jobs=-1,
                   warm_start=True
                  )

# %%
LR.fit(tf_train, X_train['isuseful'])
# Out:
# SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='log', max_iter=100, n_iter=None,
#        n_jobs=-1, penalty='l2', power_t=0.5, random_state=42, shuffle=True,
#        tol=0.0001, verbose=0, warm_start=True)

# %%
target_names=['not_useful','useful']
print(classification_report(X_test['isuseful'],
                      LR.predict(tf_test),
                     target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#  not_useful       0.73      0.70      0.71     11987
#      useful       0.71      0.74      0.72     12049
#
# avg / total       0.72      0.72      0.72     24036

# %%
# look at very bad predictions
n_examples=10
p_bad_thres = .95
high_vote_thres = 9
low_vote_thres = 0
np.random.seed(42)
print("very bad predictions")
for index, row in X_test.iloc[
    np.where(
        np.logical_and(
        np.logical_and(
            LR.predict(tf_test) != X_test['isuseful'],
            np.max(LR.predict_proba(tf_test),1) > p_bad_thres
                      ),
        X_test['useful'] >= high_vote_thres
        )
    )[0][0:n_examples]
][['text','useful']].iterrows():
    print("--------------------------------------------------------------")
    print("True Useful Votes ", row['useful'])
    print("--------------------------------------------------------------")
    print("")
    print(row['text'])
    print("")

for index, row in X_test.iloc[
    np.where(
        np.logical_and(
        np.logical_and(
            LR.predict(tf_test) != X_test['isuseful'],
            np.max(LR.predict_proba(tf_test),1) > p_bad_thres
                      ),
        X_test['useful']==0
        )
    )[0][0:n_examples]
][['text','useful']].iterrows():
    print("--------------------------------------------------------------")
    print("True Useful Votes ", row['useful'])
    print("--------------------------------------------------------------")
    print("")
    print(row['text'])
    print("")
# Out:
# very bad predictions
# --------------------------------------------------------------
# True Useful Votes  10
# --------------------------------------------------------------
#
# The place looked very clean and everyone was so courteous. The lady at the front explained to me that they're an Asian-fusion kind of place that focuses on rice bowls and chicken tenders.
#
# Located between a Dotty's and a used book store, Mochiko Chicken might seem like a hole-in-the-wall, but honestly those places are always the best.
#
# I was really craving one of the best combinations known to man: chicken and waffles. I got the Chicken Tender and Waffle Combo (2 pieces of chicken tenders and 2 waffles). The chicken tenders and the waffles were a perfect golden-brown color. The chicken tenders were amazing -- they were a perfect size and were lean and juicy. The waffles were on the crunchy side, but it was such a great pairing with the chicken. I ordered the syrup on the side so I could drizzle the perfect amount on my chicken and waffles. What better way to eat juicy chicken tenders than with waffles and syrup? This delectable combo was so AMAZING. You can also order more chicken tenders as a side item if the 2-4 strips aren't enough for you.
#
# If you're ever craving chicken, give this place a try. This is one of those places where I can't wait to go back for more!
#
# --------------------------------------------------------------
# True Useful Votes  12
# --------------------------------------------------------------
#
# Went in to have a tire patched as it had a slow leak.
# The price was reasonable and they were able to bring it directly into the shop.
# Once in the shop I realized that the key to the locking lug nuts was missing.
# The guy at Midas said he had to take the tire off ignorer too patch it.
# Unfortunately I had too leave and called the service place that did the inspection who said they could not find the key???.
# Midas was friendly and professional.
# Unfortunately I could not get my tire fixed as I did not have the key for the lug nuts.
# Definitely not Midas's fault.
# I would definitely go back too them in the future
#
# --------------------------------------------------------------
# True Useful Votes  9
# --------------------------------------------------------------
#
# Nothing about any Canadian airports have really got me impressed by any means. For the most part I feel like they don't do a great job directing air traffic when it arrives on the ground, there's extensive confusion about gates and baggage, and the bags come out slowly.
#
# Also, the food choices, even in the international area, is ... subpar at best. However, they're working on it. From what I can tell, about 80% of Montreal is under construction, so the airport is no exception. I'm sure in 8-10 years it will be great!
#
# Also, the washrooms, disgusting.
#
# --------------------------------------------------------------
# Day of the move - anyone who says younger people don't work hard just needs to spend a morning watching these guys bust their you-know-whats in 115 degree weather.  And that was after each member of the crew walked up, introduced themselves and shook my hand.  Huge thank you to Jaylen, Toren, Ramon and Juriel for both your hard work and your professionalism.  Same goes to the lead AJ - he had the inventory completely under control and was confirming and communicating with me through the entire pack up.
#
# I would absolutely recommend Just-In Time for a local move and would use them again, should the need arise.
#
# --------------------------------------------------------------
# True Useful Votes  0
# --------------------------------------------------------------
#
# If the American Medical College of Homeopathy program is accredited at PIHMA, I will have to give this school rating a minimum score.  Many students were affected by their actions when they were a stand alone homeopathy school and I would not recommend students engage in this program at PIHMA.  They hurt quite a few people with very little regard and were dishonest and non-transparent about their finances until the end.  It was very difficult for students and the integrity within their program was sub-par as far as assessing students fairly, mentoring, or in grading. While there were a few honest people in the program, most of the experiences in this program both from a leadership and student end were rather manipulating. I would encourage students to look elsewhere for this training and be very wary of any training you receive. It is not to be trusted.
#
# --------------------------------------------------------------
# True Useful Votes  0
# --------------------------------------------------------------
#
# Have used this facility, also known as SIMON15, on several occasions for MRI and CT.  Both require an appointment, which was very easy to schedule - they call you once they have the orders from your doctor, and if you miss their call, they leave a name and direct phone number for you to call them back.  Facility was packed when I went for the MRI - however - they were running on time and I was called back a few minutes BEFORE my appointment time.  When I went for a CT, about a third full, and was called back BEFORE my appointment time.  All technicians I have dealt with gave very clear information about what the procedures involved, and what I needed to do, and appeared to be very experienced and patient focused.  On one occasion I was provided with a CD to take to my doctor per his instructions, on another, the doctor had instructed that it be couriered to his office the following business day, which was done as scheduled.  Personally, despite some of the other comments in other reviews, I don't believe there is anything to complain about this location of SimonMed.  Perhaps those reviewers confused this location?
#
# --------------------------------------------------------------
# True Useful Votes  0
# --------------------------------------------------------------
#
# Since the renovation, the Bay, not just the Yorkdale location, but in general has improved in both service and merchandising. I've started to come to the bay to shop for beauty and shoes (mainly) and take advantage of their Bay day deals and HBC points that you wouldn't get else where.
#
# The bedding section downstairs is lacking. I was looking for a duvet cover and couldn't find anything less than $300 (even with a discount).
#
# But I'm in love with their beauty and shoes/accessories section. They have filled it with lots of major brand names that they did not used to have (including Ahava, not a counter, but they have the products).
#
# This location also has a spa room, for certain beauty counters. For Clarins, all you need to do is buy two facial products and you can get a free 30 min facial. During bay days, they have also lots of great gift sets and promotions. The room is great and quiet, and you'll forget you're in the busy mall for just a while.
#
# Walking around here, it's crowded and I hope that they will assess the flow between the mall and the beauty section. I"m always bumping into people.
#
# There's also a separate TopShop store off to the side.
#
# The thing that bugs me about the Bay is how everything is separated into Brands and which everything can be more together by product.
#
# --------------------------------------------------------------
# True Useful Votes  0
# --------------------------------------------------------------
#
# Going to Hoss's as a child used to be a treat I looked forward to going. But recently the brand has really gone downhill. I'm not talking about the lack of after dinner mints and smaller portions, which is also a truth of modern-day Hoss's.
#
# So let's dissect my experience tonight.
#
# Salad Bar: Nothing looked fresh despite the large crowd and it was all pretty basic. Hoss's seems stuck in the 80s where a salad bar is defined by iceberg lettuce, shredded carrots and some basic dressings mixed in house. Don't expect any arugula, sprouts or anything "gourmet." They did have some spinach, but freshness was not an adjective to describe. Aside from the mediocre salad selection they offered some garlic bread and two low quality soups. I believe a watery "French onion" comprised of all broth and a "minestrone" were the soup de jour. in all fairness the salad bar is included with the steak so expectations were low.
    np.argsort(LR.coef_).flatten()[:num_features])
)

# build the table
colnames = ['Top '+str(num_features)+' largest and smallest coefs']
rownames = []
cell_text = []
feature_names = tf_vectorizer.get_feature_names()
for x in np.ravel(ind):
    rownames.append(feature_names[x])
    row = []
    row.append("{0:.2f}".format(LR.coef_[0,x]))
    cell_text.append(row)

fig, ax = plt.subplots()
fig.set_size_inches(10, 5)
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
table = ax.table(cellText=cell_text,
                 rowLabels=rownames,
                 colLabels=colnames,
                 loc='center')
table.set_fontsize(14)
for cell in table.properties()['child_artists']:
    cell._text.set_color('black')

# %%
stop_words = ["a", "about", "above", "above", "across", "after", 
              "afterwards", "again", "against", "all", "almost", 
              "alone", "along", "already", "also","although",
              "always","am","among", "amongst", "amoungst", 
              "amount",  "an", "and", "another", "any","anyhow",
              "anyone","anything","anyway", "anywhere", "are", 
              "around", "as",  "at", "back","be","became", "because",
              "become","becomes", "becoming", "been", "before", 
              "beforehand", "behind", "being", "below", "beside", 
              "besides", "between", "beyond", "bill", "both", 
              "bottom","but", "by", "call", "can", "cannot", "cant",
              "co", "con", "could", "couldnt", "cry", "de", 
              "describe", "detail", "do", "done", "down", "due", 
              "during", "each", "eg", "eight", "either", "eleven","else", 
              "elsewhere", "empty", "enough", "etc", "even", "ever", "every",
              "everyone", "everything", "everywhere", "except", "few", 
              "fifteen", "fify", "fill", "find", "fire", "first", "five",
              "for", "former", "formerly", "forty", "found", "four", "from", 
              "front", "full", "further", "get", "give", "go", "had", "has", 
              "hasnt", "have", "he", "hence", "her", "here", "hereafter", "hereby", 
              "herein", "hereupon", "hers", "herself", "him", "himself", "his", 
              "how", "however", "hundred", "ie", "if", "in", "inc", "indeed", 
              "interest", "into", "is", "it", "its", "itself", "keep", "last", 
              "latter", "latterly", "least", "less", "ltd", "made", "many", "may",
              "me", "meanwhile", "might", "mill", "mine", "more", "moreover",
              "most", "mostly", "move", "much", "must", "my", "myself", "name", 
              "namely", "neither", "never", "nevertheless", "next", "nine", "no", 
              "nobody", "none", "noone", "nor", "not", "nothing", "now", "nowhere", 
              "of", "off", "often", "on", "once", "one", "only", "onto", "or", 
              "other", "others", "otherwise", "our", "ours", "ourselves", "out", 
              "over", "own","part", "per", "perhaps", "please", "put", "rather", 
              "re", "same", "see", "seem", "seemed", "seeming", "seems", "serious", 
              "several", "she", "should", "show", "side", "since", "sincere",
              "six", "sixty", "so", "some", "somehow", "someone", "something", 
              "sometime", "sometimes", "somewhere", "still", "such", "system", 
              "take", "ten", "than", "that", "the", "their", "them", "themselves",
              "then", "thence", "there", "thereafter", "thereby", "therefore", 
              "therein", "thereupon", "these", "they", "thickv", "thin", "third", 
              "this", "those", "though", "three", "through", "throughout", "thru", 
              "thus", "to", "together", "too", "top", "toward", "towards", "twelve", 
              "twenty", "two", "un", "under", "until", "up", "upon", "us", "very", 
              "via", "was", "we", "well", "were", "what", "whatever", "when", "whence",
              "whenever", "where", "whereafter", "whereas", "whereby", "wherein", 
              "whereupon", "wherever", "whether", "which", "while", "whither", "who", 
              "whoever", "whole", "whom", "whose", "why", "will", "with", "within", 
              "without", "would", "yet", "you", "your", "yours", "yourself", "yourselves",
              "the"]
#           1.40796826e-01,   2.19150950e-03,  -1.04875492e-01,
#          -1.21277661e-02,  -5.98313257e-03,  -2.79649637e-01,
#           2.01381789e-02,  -2.72910258e-01,  -1.21027652e-01,
#           7.99353720e-02,  -3.19410203e-02,   3.13064811e-02,
#          -1.00438856e-01,   4.71184426e-02,   5.73921709e-02,
#          -1.04644679e-01,   3.78662372e-02,   1.36027924e-01,
#          -4.17560834e-02,   2.00613639e-01,   3.00669934e-02]])

# %% [markdown]
# # Cleanup Tf-Idf w Bigrams

# %%
X_text['text']

# %%
def preprocess_text(s):
    ### STUDENT START ###

    # lowercase all
    s = s.lower()
    
    # remove commas within numbers
    s = re.sub(r'(\d)[.](\d)', r'\1\2', s)
    
    # replace long sequences of digits with 99999
    s = re.sub(r'\d{5,}', '99999', s)
    
    # replace digits with DG
    s = re.sub(r'\d{1}','DG', s)
    
    # replace hyperlinks
    s = re.sub(r"(https?:\/\/)?([\da-z\.-]+)\.([a-z\.]{2,6})([\/\w\.-]*)*\/?\S*",
              "HYPERLINK", s)
    s = re.sub(r"(HYPERLINK)+", "HYPERLINK", s)

    return s

# %%
tf_vectorizer = TfidfVectorizer(
    ngram_range=(1,2),
    lowercase=False, #done by processor
    preprocessor=preprocess_text
)
tf_train = tf_vectorizer.fit_transform(X_train['text'])
tf_test = tf_vectorizer.transform(X_test['text'])
print("size of vocabulary")
print(len(tf_vectorizer.vocabulary_))
print("")

# add star feature
tf_train = hstack((tf_train,np.array(X_train['stars'])[:,None]))
tf_test = hstack((tf_test,np.array(X_test['stars'])[:,None]))

# add review length (number of characters) feature
# X_train['length'] = X_train['text'].apply(len)
# X_test['length'] = X_test['text'].apply(len)
tf_train = hstack((tf_train,np.array(X_train['length'])[:,None]))
tf_test = hstack((tf_test,np.array(X_test['length'])[:,None]))
print("train shape",tf_train.shape)
print("test shape",tf_test.shape)
# Out:
# size of vocabulary
# 1756666
#
# train shape (60090, 1756667)
# test shape (36054, 1756667)
# train shape (60090, 1756668)
# test shape (36054, 1756668)

# %%
LR = SGDClassifier(random_state=42,
                   loss='log', #logistic regression,
                   tol=1e-4,
                   n_jobs=-1,
                   warm_start=True,
                   penalty='elasticnet'
                  )

# %%
LR.fit(tf_train, X_train['isuseful'])
target_names=['not_useful','useful']
print(classification_report(X_test['isuseful'],
                      LR.predict(tf_test),
                     target_names=target_names))

# %%
num_features = 10
# find the indexes of the highs max value features
#     for each class
# argsort finds the feature locations in ascending coef order
# flip to sort descending
ind = np.concatenate(
    (np.flip(np.argsort(LR.coef_, 1)[:, -num_features:], 1).flatten(),
    np.argsort(LR.coef_).flatten()[:num_features])
)

# build the table
colnames = ['Top '+str(num_features)+' largest and smallest coefs']
rownames = []
cell_text = []
feature_names = tf_vectorizer.get_feature_names()
for x in np.ravel(ind):
    rownames.append(feature_names[x])
    row = []
    row.append("{0:.2f}".format(LR.coef_[0,x]))
    cell_text.append(row)

fig, ax = plt.subplots()
fig.set_size_inches(10, 5)
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
table = ax.table(cellText=cell_text,
                 rowLabels=rownames,
                 colLabels=colnames,
                 loc='center')
table.set_fontsize(14)
for cell in table.properties()['child_artists']:
    cell._text.set_color('black')
